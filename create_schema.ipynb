-- %%
CREATE SCHEMA IF NOT EXISTS job_market.raw;
CREATE SCHEMA IF NOT EXISTS job_market.bronze;
CREATE SCHEMA IF NOT EXISTS job_market.silver;
CREATE SCHEMA IF NOT EXISTS job_market.gold;
CREATE SCHEMA IF NOT EXISTS job_market.meta;

CREATE VOLUME IF NOT EXISTS job_market.raw.remoteok;
